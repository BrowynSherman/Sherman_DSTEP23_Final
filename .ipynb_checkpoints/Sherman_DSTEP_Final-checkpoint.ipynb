# %% [markdown]
# # Browyn Sherman DSTEP Final

# %% [markdown]
# ## Problem Statement
#
# I am interested exploring education policy and school choice. Charter schools are one particular school choice option that have been a hot topic nationally. Charter schools are public schools that are independently operated. I am interested in exploring how charter schools compare to traditional public schools in terms of the populations they serve and the educational outcomes they achieve. I chose to focus on the state of Minnesota because they were the first state to authorize a public charter school in 1992. The Minnesota Department of Education collects data from schools and districts throughout the state and makes reports available to the public. Additional information about charter schools in the state of Minnesota is available here: https://education.mn.gov/mde/fam/cs/

# %% [markdown]
# # Data Sources
#
# ## Geospatial Data
# I used the following datasets to collect infromation about the names and locations of charter schools in Minnesota.
# 1) This dataset lists all current (as of 11-17-23) 181 charter schools in the state of Minnesota, however, it does not include geospatial data: https://public.education.mn.gov/MdeOrgView/search/tagged/MDEORG_CHARTER_LEA,MARSSOperating
# 2) This dataset includes geospatial information for various public education institutions in Minnesota: https://gisdata.mn.gov/dataset/struc-school-program-locs
# 3) This source provides geospatial data for school districts in Minnesota: https://gisdata.mn.gov/dataset/bdry-school-district-boundaries
#
# ## Enrollment Data
# I used the following datasets to collect enrollment and demographic data for charter schools in Minnesota as well as statewide data for all public schools.
# * Student enrollment data from the 2013-2014 school year through the 2022-2023 school year is available here: https://public.education.mn.gov/MDEAnalytics/DataTopic.jsp?TOPICID=2.
#
# ## Testing Data
# * This source has data on standardized testing results https://public.education.mn.gov/MDEAnalytics/DataTopic.jsp?TOPICID=1 and this source provides context: https://education.mn.gov/MDE/dse/test/mn/. This data may be useful in comparing academic outcomes between charters and traditional public schools.

# %% [markdown]
# # Dictionary
#
# ## Geospatial Data
#
# 1) Source: https://public.education.mn.gov/MdeOrgView/tag/extractContacts/MDEORG_CHARTER_LEA,MARSSOperating?description=
#
# * Organization: Column 4 lists the name of each charter school. String.
# * Physical Line 1: Column 16 includes the first line of the physical address for each school. String.
# * Physical Line 2: Column 17 contains the second line of the physical address for each school. It is empty for most schools, though some list suite numbers. String.
# * Physical City: Column 18 contains the city in which each school is physically located. String.
# * Physical State: Column 19 contains the state for the physical address for each school. It is "MN" for all rows. String.
# * Physical Zip: Column 20 contains the zip code for the physical address for each school. These are numeric values that load in as a string.
# * County: Column 21 lists the county in which each school is located. String.
# * Grades: Column 22 lists the grade levels that each school serves. String.
# * School Classification: Column 23 lists a numeric code that corresponds with a school description (i.e. Elementary School) outlined here: https://public.education.mn.gov/MdeOrgView/reference/schoolClassTypes.
# * Web URL: Column 28. This lists the website for each school. String.
#
# 2) Source: school_program_locations.csv from https://gisdata.mn.gov/dataset/struc-school-program-locs
# * ORGTYPE: Column 1. This contains a numeric value that represents the organization type. Charter schools are type 7. The key is available here https://education.mn.gov/MDE/mde074910. Integer.
# * GISNAME: Column 5. This column represents the name of the school or organization. String.
# * GISADDR: Column 8. This represents the full physical address of each institution. String.
# * WEB_URL: Column 22 contains the website url for each institution. String.
# * latitude: Column 24 is the latitude of the physical location of each institution in decimal degrees. Float.
# * longitude: Column 25 is the latitude of the physical location of each institution in decimal degrees. Float.
#
# 3)Source: school_district_boundaries.shp from https://gisdata.mn.gov/dataset/bdry-school-district-boundaries
# * PRENAME: Column 4 includes the name of each district. String.
# * WEB_URL: Column 6 lists the website url for each district. String.
# * geometry: Column 11 includes the shape of each district. Geometry.
#
# ## Enrollment Data
#
# 4) Source: Datasets retrieved from https://public.education.mn.gov/MDEAnalytics/DataTopic.jsp?TOPICID=2
#
# 2014 through 2021
# * Data Year: Column 0 lists the school year for which the data was collected. String.
# * County Name: Column 2 includes the name of the county in which the school is located. String.
# * School Name: Column 7 includes the name of the school. String.
# * Grade: Column 11 indicates the grade level for which the data was collected.School Readiness Plus and Voluntary PreKindergarten are both "PK", "ECSE" is early childhood special education. "All Grades" includes all grades PK-12. String.
# * Total Enrollment: Column 12 indicates the total number of students enrolled at the school as of October 1st of that year. Float
# * Total Female Count: Column 14 indicates the total number of female students enrolled. Float.
# * Total Male Count': Column 16 indicates the total number of male students enrolled. Float.
# * Total American Indian or Alaska Native Count: Column 18 indicates the total number of Native American students enrolled. Float.
# * Total Asian Count: Column 22 indicates the total number of Asian students enrolled. Float.
# * Total Native Hawaiian or Pacific Islander Count: Column 26 indicates the total number of Native Hawaiian or Pacific Islander Students enrolled. Float.
# * Total Hispanic or Latino Count: Column 30 indicates the total number of Hispanic or Latino students enrolled. Float.
# * Total Black or African American Count: Column 34 indicates the total number of African American Students Enrolled. Float.
# * Total White Count: Column 38 indicates the total number of white students enrolled. Float.
# * Total Two or More Races Count: Column 42 indicates the total number of students who are two or more races enrolled. Float.
# * Total Students of Color or American Indian Count: Column 46 indicates the total number of students who are not included in the white student count. Float.
# * Total Students Eligible for Free or Reduced-Priced Meals Count: Column 48 indicates the total number of students enrolled who qualify for free of reduced-price meals. Float.
# * Total Students Receiving Special Education Services Count: Column 50 indicates the total number of students enrolled recieving special education services. Float.
# * Total English learner Identified Count: Column 52 indicates the total number of students who have been identified as English language learners. Float.
# * Total Students Experiencing Homelessness Count: Column 54 indicates the total number of students enrolled who are experiencing homelessness. Float.
#
# Column numbers are different in years 2022 & 2023.
#
# # Testing Data
#
# 5) Source: Data retrieved from https://public.education.mn.gov/MDEAnalytics/DataTopic.jsp?TOPICID=1. Selected All academic accountability tests for all years in public schools accross math and reading subjects for all grades. All Academic Accountability Tests include the Minnesota Comprehensive Assessments (MCA-III) and Minnesota Test of Academic Skills (MTAS-III). Both exams test reading, math, and science. Reading exams are administered in grades 3-8 and 10 and math exams are administered in grades 3-8 and 11. No 2020 data is available due to COVID-19.
#
# * Data Year: Column 0 lists the school year for which the data was collected. String.
# * County Name: Column 2 includes the name of the county in which the school is located. String.
# * District Type: Column 4 contains a numeric value that represents the school type. Charter schools are type 7.
# * School Name: Column 7 includes the name of the school. String.
# * Grade: Column 12 indicates the grade level for which the data was collected. A grade of 00 indicates the sum of all grades for the school.
# * Subject: Column 13
# * Student Group: Column 15
# * Total Tested: 16
# * Count Level D: Column 22 indicates the number of students who, based on their test scores, do not meet standards.
# * Count Level P: Column 23 indicates the number of students who, based on their test scores, partially meet standards.
# * Count Level M: Column 24 indicates the number of students who, based on their test scores, meet standards.
# * Count Level E: Column 25 indicates the number of students who, based on their test scores, exceed standards.
# * MCA Average Score

# %%
# -- Import Useful Tools
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import plotly_express as px
import contextily as ctx
import time 

# %matplotlib notebook

# %% [markdown]
# # Maps

# %%
# -- Load source 1 data: list of current charter schools 
fname='https://public.education.mn.gov/MdeOrgView/tag/extractContacts/MDEORG_CHARTER_LEA,MARSSOperating?description='
charter_only=pd.read_csv(fname)

# -- Select useful columns
sub=[4, 16, 17, 18, 19, 20, 21, 22, 23, 28]
cols=charter_only.columns[sub]
charter_only=charter_only[cols]

# -- Remove duplicate rows
charter_only= charter_only.drop_duplicates()

# -- Remove // from website column 
split = charter_only["Web URL"].str.split("/", expand=True)
charter_only['Web_URL']=split[2]

# -- Load in source 2 data for coordinates
dpath="/Users/bls/Sherman_DSTEP23_Final/Geospatial_Data/"
fname = dpath + 'school_program_locations.csv' 
        
statewide=pd.read_csv(fname)

# -- Select Charter Schools Only (org type 7)
statewide = statewide[statewide['ORGTYPE'] == 7]

# -- Remove // from website column 
split = statewide["WEB_URL"].str.split("/", expand=True)
statewide['website']=split[2]

# -- Sub Select schools that appear in the charters dataframe
sub= statewide['website'].isin(charter_only['Web_URL'])
statewide = statewide[sub]

# -- Select useful columns
sub=[1, 5, 8, 24, 25, 26]
cols=statewide.columns[sub]
statewide=statewide[cols]

# -- Merge DataFrames 
charters = pd.merge(charter_only, statewide, right_on='website', left_on='Web_URL')

# -- Select useful columns
sub=[0, 6, 7, 8, 13, 14, 15, 16]
cols=charters.columns[sub]
charters=charters[cols]

# -- Rename columns for clarity 
charters.columns = ['school', 'county', 'grade_level', 'school_class', 'address', 'lat', 'lon', 'website']

# -- Remove duplicate rows
charters= charters.drop_duplicates(subset='website')

# -- Load in source 3 data to get District Geospatial Data
dpath="/Users/bls/Sherman_DSTEP23_Final/Geospatial_Data/"
fname1=dpath+'school_district_boundaries.shp'
districts=gpd.read_file(fname1)

# -- convert to decimal degrees
districts = districts.to_crs("epsg:4326")

# -- Display
charters
# Out:
#                             school      county grade_level  school_class  \
# 0                     City Academy      Ramsey        9-12             0
# 3             Bluffview Montessori      Winona        KG-8             0
# 5         New Heights School, Inc.  Washington       KG-12             0
# 8                Metro Deaf School      Ramsey       EC-12             0
# 11    Minnesota New Country School      Sibley       KG-12             0
# ..                             ...         ...         ...           ...
# 417  Rollingstone Community School      Winona        KG-5             0
# 418  Bultum Academy Charter School       Anoka        PK-8             0
# 419          Marine Village School  Washington        PK-8             0
# 421            Endazhi-Nitaawiging    Beltrami        KG-8             0
# 423                  Surad Academy        Rice       PK-12             0
#
#                                           address        lat        lon  \
# ...

# %%
# -- Plot charters on district map
fig, ax= plt.subplots(figsize=(10,7))
districts.plot(ax=ax, edgecolor='black', linewidth=1, facecolor='none')
charters.plot.scatter('lon', 'lat', ax=ax, color='red', s=1)
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Enrollment

# %%
# -- Load in Data 
f2014 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=MDE086207'
f2015 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=MDE086206'
f2016 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=MDE086205'
f2017 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=MDE086204'
f2018 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=MDE086203'
f2019 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=MDE086102'
f2020 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=MDE031850'
f2021 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=PROD034978'
f2022 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=PROD058443'
f2023 = 'https://education.mn.gov/mdeprod/idcplg?IdcService=GET_FILE&RevisionSelectionMethod=latestReleased&Rendition=primary&dDocName=PROD070854'

# %%
# -- Load in data by school

t0 = time.time()

sy14=pd.read_excel(f2014, sheet_name='School', skiprows=1)
sy15=pd.read_excel(f2015, sheet_name='School', skiprows=1)
sy16=pd.read_excel(f2016, sheet_name='School', skiprows=1)
sy17=pd.read_excel(f2017, sheet_name='School', skiprows=1)
sy18=pd.read_excel(f2018, sheet_name='School', skiprows=1)
sy19=pd.read_excel(f2019, sheet_name='School', skiprows=1)
sy20=pd.read_excel(f2020, sheet_name='School', skiprows=1)
sy21=pd.read_excel(f2021, sheet_name='School', skiprows=1)
sy22=pd.read_excel(f2022, sheet_name='School', skiprows=1)
sy23=pd.read_excel(f2023, sheet_name='School', skiprows=1)

t1 = time.time()
print("route calculated in {0}s".format(t1 - t0))
# Out:
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$1322.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$1364.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$1363.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: State!$1:$18.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# ...

# %%
# -- replace NaN with '0'
sy14.fillna(0, inplace=True)
sy15.fillna(0, inplace=True)
sy16.fillna(0, inplace=True)
sy17.fillna(0, inplace=True)
sy18.fillna(0, inplace=True)
sy19.fillna(0, inplace=True)
sy20.fillna(0, inplace=True)
sy21.fillna(0, inplace=True)
sy22.fillna(0, inplace=True)
sy23.fillna(0, inplace=True)

# -- Select Charter Schools Only (district type 7)
sy14_sub=sy14[sy14['District Type'] == 7]
sy15_sub=sy15[sy15['District Type'] == 7]
sy16_sub=sy16[sy16['District Type'] == 7]
sy17_sub=sy17[sy17['District Type'] == 7]
sy18_sub=sy18[sy18['District Type'] == 7]
sy19_sub=sy19[sy19['District Type'] == 7]
sy20_sub=sy20[sy20['District Type'] == 7]
sy21_sub=sy21[sy21['District Type'] == 7]
sy22_sub=sy22[sy22['District Type'] == 7]
sy23_sub=sy23[sy23['District Type'] == 7]

# -- Select data for all grades 
sy14_sub1=sy14_sub[sy14_sub['Grade'] == 'All Grades']
sy15_sub1=sy15_sub[sy15_sub['Grade'] == 'All Grades']
sy16_sub1=sy16_sub[sy16_sub['Grade'] == 'All Grades']
sy17_sub1=sy17_sub[sy17_sub['Grade'] == 'All Grades']
sy18_sub1=sy18_sub[sy18_sub['Grade'] == 'All Grades']
sy19_sub1=sy19_sub[sy19_sub['Grade'] == 'All Grades']
sy20_sub1=sy20_sub[sy20_sub['Grade'] == 'All Grades']
sy21_sub1=sy21_sub[sy21_sub['Grade'] == 'All Grades']
sy22_sub1=sy22_sub[sy22_sub['Grade'] == 'All Grades']
sy23_sub1=sy23_sub[sy23_sub['Grade'] == 'All Grades']

# -- Select only useful columns for 2014-2021
sub = [0, 2, 7, 11, 12, 14, 16, 18, 22, 26, 30, 34, 38, 42, 46, 48, 50, 52, 54]
cols1 = sy14_sub1.columns[sub]
cols2 = sy15_sub1.columns[sub]
cols3 = sy16_sub1.columns[sub]
cols4 = sy17_sub1.columns[sub]
cols5 = sy18_sub1.columns[sub]
cols6 = sy19_sub1.columns[sub]
cols7 = sy20_sub1.columns[sub]
cols8 = sy21_sub1.columns[sub]
sy14_sub2 = sy14_sub1[cols1]
sy15_sub2 = sy15_sub1[cols2]
sy16_sub2 = sy16_sub1[cols3]
sy17_sub2 = sy17_sub1[cols4]
sy18_sub2 = sy18_sub1[cols5]
sy19_sub2 = sy19_sub1[cols6]
sy20_sub2 = sy20_sub1[cols7]
sy21_sub2 = sy21_sub1[cols8]

# -- Select only useful columns for 2022
sub1 = [0, 2, 7, 11, 12, 14, 16, 18, 22, 26, 30, 34, 38, 42, 46, 52, 54, 56, 58]
cols9 = sy22_sub1.columns[sub1]
sy22_sub2 = sy22_sub1[cols9]

# -- Select only useful columns for 2023
sub2 = [0, 2, 7, 11, 12, 14, 16, 18, 22, 26, 30, 34, 42, 46, 50, 52, 54, 56, 58]
cols10 = sy23_sub1.columns[sub2]
sy23_sub2= sy23_sub1[cols10]

# -- Adjust column names for consistency and clarity 
sy14_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy15_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy16_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy17_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy18_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy19_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy20_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy21_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy22_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
sy23_sub2.columns=['year', 'county', 'school', 'grades', 'total_enrollment', 'female', 'male', 'native', 'asian', 'black', 'hispanic/latino', 'hi/pi', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']

# -- group by year and sum
sygrp14=sy14_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp15=sy15_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp16=sy16_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp17=sy17_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp18=sy18_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp19=sy19_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp20=sy20_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp21=sy21_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp22=sy22_sub2.groupby("year").sum(numeric_only=True).reset_index()
sygrp23=sy23_sub2.groupby("year").sum(numeric_only=True).reset_index()

# -- combine results into a single dataframe
charter_demo = pd.concat([sygrp14, sygrp15, sygrp16, sygrp17, sygrp18, sygrp19, sygrp20, sygrp21, sygrp22, sygrp23], ignore_index=True)
charter_demo
# Out:
#     year  total_enrollment   female     male  native    asian  hi/pi  \
# 0  13-14           43937.0  22294.0  21643.0   659.0   6279.0   42.0
# 1  14-15           47747.0  24204.0  23543.0   681.0   6616.0   30.0
# 2  15-16           50812.0  25829.0  24983.0   677.0   7238.0   39.0
# 3  16-17           54211.0  27459.0  26752.0   745.0   8044.0   32.0
# 4  17-18           56769.0  28655.0  28114.0   783.0   8876.0   37.0
# 5  18-19           59482.0  30005.0  29477.0   840.0   9737.0   42.0
# 6  19-20           62751.0  31619.0  31132.0   926.0  10305.0   43.0
# 7  20-21           65987.0  33397.0  32590.0   964.0  10585.0   46.0
# 8  21-22           66595.0  33578.0  33017.0   945.0  10694.0   42.0
# 9  22-23           67890.0  34264.0  33626.0  1745.0  11040.0   49.0
#
#    hispanic/latino    black    white   multi      poc  free_meals    sped  \
# 0           4146.0  10829.0  20485.0  1497.0  23452.0     12240.0  5443.0
# ...

# %%
# -- Load in Data for the State 
MN14=pd.read_excel(f2014, sheet_name='State', skiprows=1)
MN15=pd.read_excel(f2015, sheet_name='State', skiprows=1)
MN16=pd.read_excel(f2016, sheet_name='State', skiprows=1)
MN17=pd.read_excel(f2017, sheet_name='State', skiprows=1)
MN18=pd.read_excel(f2018, sheet_name='State', skiprows=1)
MN19=pd.read_excel(f2019, sheet_name='State', skiprows=1)
MN20=pd.read_excel(f2020, sheet_name='State', skiprows=1)
MN21=pd.read_excel(f2021, sheet_name='State', skiprows=1)
MN22=pd.read_excel(f2022, sheet_name='State', skiprows=1)
MN23=pd.read_excel(f2023, sheet_name='State', skiprows=1)

# -- replace NaN with '0'
MN14.fillna(0, inplace=True)
MN15.fillna(0, inplace=True)
MN16.fillna(0, inplace=True)
MN17.fillna(0, inplace=True)
MN18.fillna(0, inplace=True)
MN19.fillna(0, inplace=True)
MN20.fillna(0, inplace=True)
MN21.fillna(0, inplace=True)
MN22.fillna(0, inplace=True)
MN23.fillna(0, inplace=True)

# -- Select data for all grades 
MN14_sub=MN14[MN14['Grade'] == 'All Grades']
MN15_sub=MN15[MN15['Grade'] == 'All Grades']
MN16_sub=MN16[MN16['Grade'] == 'All Grades']
MN17_sub=MN17[MN17['Grade'] == 'All Grades']
MN18_sub=MN18[MN18['Grade'] == 'All Grades']
MN19_sub=MN19[MN19['Grade'] == 'All Grades']
MN20_sub=MN20[MN20['Grade'] == 'All Grades']
MN21_sub=MN21[MN21['Grade'] == 'All Grades']
MN22_sub=MN22[MN22['Grade'] == 'All Grades']
MN23_sub=MN23[MN23['Grade'] == 'All Grades']

# -- Select useful columns for 2014-2021
sub3 = [0, 11, 12, 14, 16, 18, 22, 26, 30, 34, 38, 42, 46, 48, 50, 52, 54]
cols1 = MN14_sub.columns[sub3]
cols2 = MN15_sub.columns[sub3]
cols3 = MN16_sub.columns[sub3]
cols4 = MN17_sub.columns[sub3]
cols5 = MN18_sub.columns[sub3]
cols6 = MN19_sub.columns[sub3]
cols7 = MN20_sub.columns[sub3]
cols8 = MN21_sub.columns[sub3]
MN14_sub1 = MN14_sub[cols1]
MN15_sub1 = MN15_sub[cols2]
MN16_sub1 = MN16_sub[cols3]
MN17_sub1 = MN17_sub[cols4]
MN18_sub1 = MN18_sub[cols5]
MN19_sub1 = MN19_sub[cols6]
MN20_sub1 = MN20_sub[cols7]
MN21_sub1 = MN21_sub[cols8]

# -- Select useful columns for 2022
sub4 = [0, 11, 12, 14, 16, 18, 22, 26, 30, 34, 38, 42, 46, 52, 54, 56, 58]
cols9 = MN22_sub.columns[sub4]
MN22_sub1 = MN22_sub[cols9]

# -- Select only useful columns for 2023
sub5 = [0, 11, 12, 14, 16, 18, 22, 26, 30, 34, 42, 46, 50, 52, 54, 56, 58]
cols10 = MN23_sub.columns[sub5]
MN23_sub1 = MN23_sub[cols10]

# -- group by year and sum
MNgrp14=MN14_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp15=MN15_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp16=MN16_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp17=MN17_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp18=MN18_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp19=MN19_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp20=MN20_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp21=MN21_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp22=MN22_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()
MNgrp23=MN23_sub1.groupby("Data Year").sum(numeric_only=True).reset_index()

# -- Adjust column names for consistency and clarity 
MNgrp14.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp15.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp16.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp17.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp18.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp19.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp20.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp21.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp22.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'hi/pi', 'hispanic/latino', 'black', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']
MNgrp23.columns=['year', 'total_enrollment', 'female', 'male', 'native', 'asian', 'black', 'hispanic/latino', 'hi/pi', 'white', 'multi', 'poc', 'free_meals', 'sped', 'ell', 'homeless']

# -- combine results into a single dataframe
MN_demo = pd.concat([MNgrp14, MNgrp15, MNgrp16, MNgrp17, MNgrp18, MNgrp19, MNgrp20, MNgrp21, MNgrp22, MNgrp23], ignore_index=True)
MN_demo
# Out:
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$1322.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$1364.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$1363.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: State!$1:$18.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# ...

# %%
# -- Plot enrollment trends over time for charter schools
fig, ax = plt.subplots(figsize=(10, 7))
charter_demo.plot.line(x='year', y='total_enrollment', label='Charter Schools', color='r', ax=ax)
plt.xlabel("School Year")  
plt.ylabel("Total Number of Students Enrolled")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the total number of students enrolled in charter schools in the State of Minnesota as a function of time between the 2013-2014 school year and the 2022-2023 school year. The number of charter school students ranges from less than 45,000 to more than 65,000 and appears to increase steadily over time. Enrollment seems to plateau slightly between the 19-20 and 21-22 school years, though there is never a decrease in enrollment.

# %%
# -- Plot enrollment trends over time for all public schools
fig, ax = plt.subplots(figsize=(10, 7))
MN_demo.plot.line(x='year', y='total_enrollment', label='All Public Schools', color='b', ax=ax)
plt.xlabel("School Year")  
plt.ylabel("Total Number of Students Enrolled")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the total number of students enrolled in public schools in the State of Minnesota as a function of time between the 2013-2014 school year and the 2022-2023 school year. The number of students ranges from just over 850,000 to more than 890,000. Enrollment appears to increase between the 13-14 and 19-20 school years. There is a steep drop off between 19-20 and 21-22 of approximately 20,000 students. This decrease may be explained by the COVID-19 pandemic. It is interesting that traditional public school enrollment appears to have been affected more than charter school enrollment.

# %%
# -- Find Percentage of the Public Student Population Served by Charter Schools Over Time
charter_demo['% of all students served']=charter_demo['total_enrollment']/MN_demo['total_enrollment']* 100

# -- Plot Result
fig, ax = plt.subplots(figsize=(10, 7))
charter_demo.plot.bar(x='year', y='% of all students served', legend=None, color='r', ax=ax)
plt.xlabel("School Year")  
plt.ylabel("Percentage of the Public School Population Served by Charter Schools")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the percentage of the public school population served by charter schools as a function of time between the 2013-2014 school year and the 2022-2023 school year. Charter schools served just over 5% of the state's public school students in 2013-14. That number has risen over time, and in 2022-23, charter schools served nearly 8% of the state's public school students.

# %%
# -- Calculate % of white students served versus students of color
charter_demo['white %']=charter_demo['white']/charter_demo['total_enrollment']* 100
charter_demo ['poc %']=charter_demo['poc']/charter_demo['total_enrollment']* 100
MN_demo['white %']=MN_demo['white']/MN_demo['total_enrollment']*100
MN_demo ['poc %']=MN_demo['poc']/MN_demo['total_enrollment']*100
charter_demo['% of white statewide served by charters']= charter_demo['white']/MN_demo['white']*100
charter_demo['% of all poc statewide served by charters'] = charter_demo['poc']/MN_demo['poc']*100

# -- Plot enrollment trends for students of color over time
fig, ax = plt.subplots(figsize=(10, 7))
charter_demo.plot.bar(x='year', y='poc %', label='Charter Schools', position=0, color='r', ax=ax, width=0.4)
MN_demo.plot.bar(x='year', y='poc %', label='All Public Schools', position=1, color='b', ax=ax, width=0.4)
plt.xlabel("School Year")  
plt.ylabel("% of student population by school type that identifies as POC")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the percentage of the student population comprised of persons of color in Minnesota, as a function of time, between the 2013-2014 school year and the 2022-2023 school year. The charter school student population appears in red, while the statewide public school population appears in blue. In both cases, the overall percentage of students of color appears to have increased slightly over time. About 30%-35% of Minnesota public school students are persons of color. In the state's charter schools, a much higher percentage of students are persons of color at about 55%-60%. This suggests that charter schools are serving a higher percentage of students of color.

# %%
# -- Calculate averages from '14 through '23
charter_white=charter_demo['white %'].mean()
charter_poc=charter_demo ['poc %'].mean()
MN_white=MN_demo['white %'].mean()
MN_poc=MN_demo ['poc %'].mean()
charterpct_white=charter_demo['% of white statewide served by charters'].mean()
charterpct_poc=charter_demo['% of all poc statewide served by charters'].mean()

# -- Print results
print('Between the 2013-2014 school year and the 2022-2023 school year,', round(MN_white),'% of public school students in the state of Minnesota were white, while the average percentage of students of color was', round(MN_poc),'%.') 
print('')   
print('Between the 2013-2014 school year and the 2022-2023 school year,', round(charter_white),'% of charter school students in the state of Minnesota were white, while the average percentage of students of color was', round(charter_poc),'%.') 
print('') 
print('Between the 2013-2014 school year and the 2022-2023 school year, charter schools served', round(charterpct_white), '% of the white public school student population in the state of Minnesota, on average, and',round(charterpct_poc), '% of public school students of color.')
# Out:
# Between the 2013-2014 school year and the 2022-2023 school year, 66 % of public school students in the state of Minnesota were white, while the average percentage of students of color was 34 %.
#
# Between the 2013-2014 school year and the 2022-2023 school year, 41 % of charter school students in the state of Minnesota were white, while the average percentage of students of color was 59 %.
#
# Between the 2013-2014 school year and the 2022-2023 school year, charter schools served 4 % of the white public school student population in the state of Minnesota, on average, and 12 % of public school students of color.

# %%
# -- Look at range of the percentage of POC students served by charter schools 
    # --There will be more than 181 charter schools because schools have opened and/or closed during this timeframe

# -- combine results into a single dataframe
all_charters=pd.concat([sy14_sub2, sy15_sub2, sy16_sub2, sy17_sub2, sy18_sub2, sy19_sub2, sy20_sub2, sy21_sub2, sy22_sub2, sy23_sub2], ignore_index=True)


# -- convert school names to all lower case
all_charters['school'] = all_charters['school'].str.lower()

# -- group by school and sum
cgrp=all_charters.groupby("school").sum(numeric_only=True).reset_index()

# -- Calculate % of white students served versus students of color
cgrp['% white']=round(cgrp['white']/cgrp['total_enrollment']* 100)
cgrp ['% poc']=round(cgrp['poc']/cgrp['total_enrollment']* 100)

# -- Sort values from lowest to highest
charter_sort= cgrp.sort_values("% poc")
charter_sort
# Out:
#                                       school  total_enrollment  female  \
# 211               milroy area charter school             206.0   116.0
# 363                      starland elementary              78.0    35.0
# 166  la crescent montessori and stem academy              42.0    20.0
# 238              nasha shkola charter school            1218.0   591.0
# 200                    marine village school              29.0    16.0
# ..                                       ...               ...     ...
# 340         skyline math and science academy            1095.0   549.0
# 203                       metro college prep             882.0   391.0
# 205                    metro schools charter            2179.0  1101.0
# 207            metro tech academy elementary             105.0    49.0
# 138            hmong college prep academy es            5227.0  2569.0
#
#        male  native   asian  hi/pi  hispanic/latino   black   white  multi  \
# ...

# %%
# -- Plot histogram
fig, ax = plt.subplots(figsize=(10, 7))
charter_sort.reset_index().plot.hist(x='index', y='% poc', label='Charter Schools', color='r', ax=ax, bins=20)
plt.xlabel("Average % of POC students per school (from '13-'14 to '22-'23)")
plt.ylabel("Number of Charter Schools")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This histogram illustrates the number of charter schools in Minnesota that existed between 2013 and 2023, by the average percentage of the school's student body that are students of color. There are more than 150 charter schools of 420 that, on average, serve more than 80% students of color.

# %%
sum_zeros = charter_sort[charter_sort['% poc'] == 0.0]['% poc'].count()
sum_hundreds = charter_sort[charter_sort['% poc'] == 100.0]['% poc'].count()

print(f'There have been {sum_zeros} Charter schools that have operated between the 2013-2014 school year and the 2022-2023 school year that have served 0% students of color on average.')
print('')
print(f'There have been {sum_hundreds} Charter schools that have operated between the 2013-2014 school year and the 2022-2023 school year that have served 100% students of color on average.')
print('')
print('Approximately 20% (86/420) of Charter schools that operated between the 2013-2014 school year and the 2022-2023 school year serve only students of color.')
# Out:
# There have been 3 Charter schools that have operated between the 2013-2014 school year and the 2022-2023 school year that have served 0% students of color on average.
#
# There have been 86 Charter schools that have operated between the 2013-2014 school year and the 2022-2023 school year that have served 100% students of color on average.
#
# Approximately 20% (86/420) of Charter schools that operated between the 2013-2014 school year and the 2022-2023 school year serve only students of color.

# %%
# -- Calculate % of students served who are English language learners
charter_demo['% ell']=charter_demo['ell']/charter_demo['total_enrollment']* 100
MN_demo['% ell']=MN_demo['ell']/MN_demo['total_enrollment']*100

# -- Plot enrollment trends for students of color over time
fig, ax = plt.subplots(figsize=(10, 7))
charter_demo.plot.bar(x='year', y='% ell', label='Charter Schools', position=0, color='r', ax=ax, width=0.4)
MN_demo.plot.bar(x='year', y='% ell', label='All Public Schools', position=1, color='b', ax=ax, width=0.4)
plt.xlabel("School Year")  
plt.ylabel("% of student population by school type that are English language learners")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the percentage of the student population comprised of English language learners in Minnesota, as a function of time, between the 2013-2014 school year and the 2022-2023 school year. The charter school student population appears in red, while the statewide public school population appears in blue. About 8% of Minnesota public school students are English language learners. In the state's charter schools, a much higher percentage of students are English language learners at about 20%. This suggests that charter schools are serving a higher percentage of English language learners.

# %%
# -- Calculate averages from '14 through '23
charter_ell = charter_demo['% ell'].mean()
MN_ell = MN_demo['% ell'].mean()

# -- Print results
print('Between the 2013-2014 school year and the 2022-2023 school year,', round(MN_ell), '% of public school students in the state of Minnesota were English Language Learners.')
print('')   
print(round(charter_ell), '% of charter school students in the state of Minnesota were English language learners.')
# Out:
# Between the 2013-2014 school year and the 2022-2023 school year, 8 % of public school students in the state of Minnesota were English Language Learners.
#
# 20 % of charter school students in the state of Minnesota were English language learners.

# %%
# -- Calculate % of students served who are experiencing homelessness
charter_demo['% homeless']=charter_demo['homeless']/charter_demo['total_enrollment']* 100
MN_demo['% homeless']=MN_demo['homeless']/MN_demo['total_enrollment']*100

# -- Plot enrollment trends for students of color over time
fig, ax = plt.subplots(figsize=(10, 7))
charter_demo.plot.bar(x='year', y='% homeless', label='Charter Schools', position=0, color='r', ax=ax, width=0.4)
MN_demo.plot.bar(x='year', y='% homeless', label='All Public Schools', position=1, color='b', ax=ax, width=0.4)
plt.xlabel("School Year")  
plt.ylabel("% of student population by school type that are experiencing homelessness")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the percentage of the student population experiencing homelessness in Minnesota, as a function of time, between the 2013-2014 school year and the 2022-2023 school year. The charter school student population appears in red, while the statewide public school population appears in blue. The number of students experiencing homelessness appears to drop in 2020, which could be explained by eviction moritoriums enacted during the COVID-19 pandemic, or by challenges collecting data when students were learning remotely. About .75%-1% of Minnesota public school students experienced homelessness during this timeframe. In the state's charter schools, a higher percentage of students experienced homelessness at about 1.25%-2%. This suggests that charter schools are serving a higher percentage of students experiencing homelessness.

# %%
# -- Calculate % of students served who qualify for reduced-price or free meals 
charter_demo['% free_meals']=charter_demo['free_meals']/charter_demo['total_enrollment']* 100
MN_demo['% free_meals']=MN_demo['free_meals']/MN_demo['total_enrollment']*100

# -- Plot enrollment trends for students of color over time
fig, ax = plt.subplots(figsize=(10, 7))
charter_demo.plot.bar(x='year', y='% free_meals', label='Charter Schools', position=0, color='r', ax=ax, width=0.4)
MN_demo.plot.bar(x='year', y='% free_meals', label='All Public Schools', position=1, color='b', ax=ax, width=0.4)
plt.xlabel("School Year")  
plt.ylabel("% of student population by school type that qualifies for free or reduced-price meals")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the percentage of the student population that qualifies for free or reduced-price meals in Minnesota, as a function of time, between the 2013-2014 school year and the 2022-2023 school year. The charter school student population appears in red, while the statewide public school population appears in blue. For all Minnesota public schools and for charter schools, these students represent around 30-45% of the population. from 2013-2014 to 2017-2018, charter schools were generally serving fewer students who qualified for free or reduced-price meals than the state avergae. In the 18-19 and 19-20 school years, charter schools served about the same percentage of students that qualified statewide. During the pandemic, in 20-21 and 21-22, charter schools served a higher percentage of qualifying students than the state average. In the 22-23 school year, the average number of qualifying students jumped to over 40% and charter schools only had around 38% of their student poppulation qualifying for free or reduced-price meals.

# %%
# -- Calculate % of students served who utilize special education services
charter_demo['% sped']=charter_demo['sped']/charter_demo['total_enrollment']* 100
MN_demo['% sped']=MN_demo['sped']/MN_demo['total_enrollment']*100

# -- Plot enrollment trends for students of color over time
fig, ax = plt.subplots(figsize=(10, 7))
charter_demo.plot.bar(x='year', y='% sped', label='Charter Schools', position=0, color='r', ax=ax, width=0.4)
MN_demo.plot.bar(x='year', y='% sped', label='All Public Schools', position=1, color='b', ax=ax, width=0.4)
plt.xlabel("School Year")  
plt.ylabel("% of student population by school type that use special education services")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# Caption: This figure illustrates the percentage of the student population receiving special education services in Minnesota, as a function of time, between the 2013-2014 school year and the 2022-2023 school year. The charter school student population appears in red, while the statewide public school population appears in blue. In both cases, the overall percentage of students receiving special education services appears to have increased slightly over time. About 15%-17% of Minnesota public school students use special education services. In the state's charter schools, a lower percentage of students use these services at about 12.5%. This suggests that charter schools are either serving a lower percentage of students with disabilities or providing fewer special education services.

# %% [markdown]
# # Testing Data

# %%
# -- Load in Data 
dpath2="/Users/bls/Sherman_DSTEP23_Final/Testing_Data/"

math23_file=dpath2+'math23.xlsx'
math22_file=dpath2+'math22.xlsx'
math21_file=dpath2+'math21.xlsx'
math19_file=dpath2+'math19.xlsx'
reading23_file=dpath2+'reading23.xlsx'
reading22_file=dpath2+'reading22.xlsx'
reading21_file=dpath2+'reading21.xlsx'
reading19_file=dpath2+'reading19.xlsx'

# %%
# -- Load in Data by School 
t0 = time.time()

charter_math_23= pd.read_excel(math23_file, sheet_name='School')
charter_reading_23=pd.read_excel(reading23_file, sheet_name='School')

charter_math_22= pd.read_excel(math22_file, sheet_name='School')
charter_reading_22=pd.read_excel(reading22_file, sheet_name='School')

charter_math_21= pd.read_excel(math21_file, sheet_name='School', skiprows=1)
charter_reading_21=pd.read_excel(reading21_file, sheet_name='School', skiprows=1)

charter_math_19= pd.read_excel(math19_file, sheet_name='School')
charter_reading_19=pd.read_excel(reading19_file, sheet_name='School')

t1 = time.time()
print("route calculated in {0}s".format(t1 - t0))
# Out:
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$14291.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: District!$1:$66850.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: School!$1:$136742.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: State!$1:$202.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# ...

# %%
# -- Select Charter Schools Only (district type 7)
charter_math23_sub=charter_math_23[charter_math_23['District Type'] == 7]
charter_math22_sub=charter_math_22[charter_math_22['District Type'] == 7]
charter_math21_sub=charter_math_21[charter_math_21['District Type'] == 7]
charter_math19_sub=charter_math_19[charter_math_19['District Type'] == 7]
charter_reading23_sub=charter_reading_23[charter_reading_23['District Type'] == 7]
charter_reading22_sub=charter_reading_22[charter_reading_22['District Type'] == 7]
charter_reading21_sub=charter_reading_21[charter_reading_21['District Type'] == 7]
charter_reading19_sub=charter_reading_19[charter_reading_19['District Type'] == 7]

# -- Select All Grades
charter_math23_sub1 = charter_math23_sub[(charter_math23_sub['Grade'] == 0.0)]
charter_math22_sub1 = charter_math22_sub[(charter_math22_sub['Grade'] == 0)]
charter_math21_sub1 = charter_math21_sub[(charter_math21_sub['Grade'] == 0.0)]
charter_math19_sub1 = charter_math19_sub[(charter_math19_sub['Grade'] == 0)]
charter_reading23_sub1 = charter_reading23_sub[(charter_reading23_sub['Grade'] == 0.0)]                              
charter_reading22_sub1 = charter_reading22_sub[(charter_reading22_sub['Grade'] == 0)]
charter_reading21_sub1 = charter_reading21_sub[(charter_reading21_sub['Grade'] == 0.0)]
charter_reading19_sub1 = charter_reading19_sub[(charter_reading19_sub['Grade'] == 0)]

# -- Select All Students
charter_math23_sub2 = charter_math23_sub1[(charter_math23_sub1['Student Group'] == 'All students')]
charter_math22_sub2 = charter_math22_sub1[(charter_math22_sub1['Student Group'] == 'All students')]
charter_math21_sub2 = charter_math21_sub1[(charter_math21_sub1['Student Group'] == 'All students')] 
charter_math19_sub2 = charter_math19_sub1[(charter_math19_sub1['Student Group'] == 'All students')] 
charter_reading23_sub2 = charter_reading23_sub1[(charter_reading23_sub1['Student Group'] == 'All students')]                              
charter_reading22_sub2 = charter_reading22_sub1[(charter_reading22_sub1['Student Group'] == 'All students')] 
charter_reading21_sub2 = charter_reading21_sub1[(charter_reading21_sub1['Student Group'] == 'All students')] 
charter_reading19_sub2 = charter_reading19_sub1[(charter_reading19_sub1['Student Group'] == 'All students')] 

# -- Select only useful columns for 2021-2021
sub = [0, 2, 7, 12, 13, 15, 16, 22, 23, 24, 25, 31]
cols1 = charter_math23_sub2.columns[sub]
cols2 = charter_math22_sub2.columns[sub]
cols3 = charter_math21_sub2.columns[sub]
cols5 = charter_reading23_sub2.columns[sub]
cols6 = charter_reading22_sub2.columns[sub]
cols7 = charter_reading21_sub2.columns[sub]
charter_math23_all = charter_math23_sub2[cols1]
charter_math22_all = charter_math22_sub2[cols2]
charter_math21_all = charter_math21_sub2[cols3]
charter_reading23_all = charter_reading23_sub2[cols5]
charter_reading22_all = charter_reading22_sub2[cols6]
charter_reading21_all = charter_reading21_sub2[cols7]

# -- Select only useful columns for 2019
sub1 = [0, 2, 7, 12, 13, 15, 16, 23, 24, 25, 26, 32]
cols4 = charter_math19_sub2.columns[sub1]
charter_math19_all = charter_math19_sub2[cols4]
cols8 = charter_reading19_sub2.columns[sub1]
charter_reading19_all = charter_reading19_sub2[cols8]

# -- Adjust column names for consistency and clarity 
charter_math23_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
charter_math22_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
charter_math21_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
charter_math19_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
charter_reading23_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
charter_reading22_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
charter_reading21_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
charter_reading19_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']

# -- Replace 'no data' with NaN
charter_math23_all.replace('no data', np.nan, inplace=True)
charter_math22_all.replace('no data', np.nan, inplace=True)
charter_reading23_all.replace('no data', np.nan, inplace=True)
charter_reading22_all.replace('no data', np.nan, inplace=True)

# -- Drop NaNs in Count Level D Column
charter_math23_all.dropna(subset=['meets'], inplace=True)
charter_math22_all.dropna(subset=['meets'], inplace=True)
charter_math21_all.dropna(subset=['meets'], inplace=True)
charter_math19_all.dropna(subset=['meets'], inplace=True)
charter_reading23_all.dropna(subset=['meets'], inplace=True)
charter_reading22_all.dropna(subset=['meets'], inplace=True)
charter_reading21_all.dropna(subset=['meets'], inplace=True)
charter_reading19_all.dropna(subset=['meets'], inplace=True)

# -- group by year and sum
cmath23=charter_math23_all.groupby("year").sum().reset_index()
cmath22=charter_math22_all.groupby("year").sum().reset_index()
cmath21=charter_math21_all.groupby("year").sum().reset_index()
cmath19=charter_math19_all.groupby("year").sum().reset_index()
cread23=charter_reading23_all.groupby("year").sum().reset_index()
cread22=charter_reading22_all.groupby("year").sum().reset_index()
cread21=charter_reading21_all.groupby("year").sum().reset_index()
cread19=charter_reading19_all.groupby("year").sum().reset_index()

# -- combine results into a single dataframe
charter_test = pd.concat([cmath23, cmath22, cmath21, cmath19, cread23, cread22, cread21, cread19])
charter_test
# Out:
# /var/folders/n4/qn58pcqs793_pw6d4r2zlbjc0000gn/T/ipykernel_75247/3209480582.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charter_math23_all.replace('no data', np.nan, inplace=True)
# /var/folders/n4/qn58pcqs793_pw6d4r2zlbjc0000gn/T/ipykernel_75247/3209480582.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   charter_math22_all.replace('no data', np.nan, inplace=True)
# /var/folders/n4/qn58pcqs793_pw6d4r2zlbjc0000gn/T/ipykernel_75247/3209480582.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# -- Load in Data for the State 
t0 = time.time()

MN_math_23= pd.read_excel(math23_file, sheet_name='State')
MN_reading_23=pd.read_excel(reading23_file, sheet_name='State')

MN_math_22= pd.read_excel(math22_file, sheet_name='State')
MN_reading_22=pd.read_excel(reading22_file, sheet_name='State')

MN_math_21= pd.read_excel(math21_file, sheet_name='State', skiprows=1)
MN_reading_21=pd.read_excel(reading21_file, sheet_name='State', skiprows=1)

MN_math_19= pd.read_excel(math19_file, sheet_name='State')
MN_reading_19=pd.read_excel(reading19_file, sheet_name='State')

t1 = time.time()
print("route calculated in {0}s".format(t1 - t0))
# Out:
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: County!$1:$14291.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: District!$1:$66850.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: School!$1:$136742.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# /Users/bls/anaconda3/lib/python3.11/site-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: State!$1:$202.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
# ...

# %%
MN_math_23
# Out:
#              Data Year County Number County Name  District Number  \
# 0                22-23       no data     no data           9999.0
# 1                22-23       no data     no data           9999.0
# 2                22-23       no data     no data           9999.0
# 3                22-23       no data     no data           9999.0
# 4                22-23       no data     no data           9999.0
# ..                 ...           ...         ...              ...
# 196              22-23       no data     no data           9999.0
# 197              22-23       no data     no data           9999.0
# 198              22-23       no data     no data           9999.0
# 199              22-23       no data     no data           9999.0
# 200  end of worksheet            NaN         NaN              NaN
#
#      District Type District Name School Number School Name ECSU Number  \
# 0             99.0     STATEWIDE       no data     no data
# ...

# %%
# -- Select All Grades
MN_math23_sub = MN_math_23[(MN_math_23['Grade'] == 0.0)]
MN_math22_sub = MN_math_22[(MN_math_22['Grade'] == 0)]
MN_math21_sub = MN_math_21[(MN_math_21['Grade'] == 0.0)]
MN_math19_sub = MN_math_19[(MN_math_19['Grade'] == 0)]
MN_reading23_sub = MN_reading_23[(MN_reading_23['Grade'] == 0.0)]                              
MN_reading22_sub = MN_reading_22[(MN_reading_22['Grade'] == 0)]
MN_reading21_sub = MN_reading_21[(MN_reading_21['Grade'] == 0.0)]
MN_reading19_sub = MN_reading_19[(MN_reading_19['Grade'] == 0)]

# -- Select All Students
MN_math23_sub1 = MN_math23_sub[(MN_math23_sub['Student Group'] == 'All students')]
MN_math22_sub1 = MN_math22_sub[(MN_math22_sub['Student Group'] == 'All students')]
MN_math21_sub1 = MN_math21_sub[(MN_math21_sub['Student Group'] == 'All students')]
MN_math19_sub1 = MN_math19_sub[(MN_math19_sub['Student Group'] == 'All students')]
MN_reading23_sub1 = MN_reading23_sub[(MN_reading23_sub['Student Group'] == 'All students')]
MN_reading22_sub1 = MN_reading22_sub[(MN_reading22_sub['Student Group'] == 'All students')]
MN_reading21_sub1 = MN_reading21_sub[(MN_reading21_sub['Student Group'] == 'All students')]
MN_reading19_sub1 = MN_reading19_sub[(MN_reading19_sub['Student Group'] == 'All students')]

# -- Select only useful columns for 2021-2021
sub = [0, 2, 7, 12, 13, 15, 16, 22, 23, 24, 25, 31]
cols1 = MN_math23_sub1.columns[sub]
cols2 = MN_math22_sub1.columns[sub]
cols3 = MN_math21_sub1.columns[sub]
cols5 = MN_reading23_sub1.columns[sub]
cols6 = MN_reading22_sub1.columns[sub]
cols7 = MN_reading21_sub1.columns[sub]
MN_math23_all = MN_math23_sub1[cols1]
MN_math22_all = MN_math22_sub1[cols2]
MN_math21_all = MN_math21_sub1[cols3]
MN_reading23_all = MN_reading23_sub1[cols5]
MN_reading22_all = MN_reading22_sub1[cols6]
MN_reading21_all = MN_reading21_sub1[cols7]

# -- Select only useful columns for 2019
sub1 = [0, 2, 7, 12, 13, 15, 16, 23, 24, 25, 26, 32]
cols4 = MN_math19_sub1.columns[sub1]
cols8 = MN_reading19_sub1.columns[sub1]
MN_math19_all = MN_math19_sub1[cols8]
MN_reading19_all = MN_reading19_sub1[cols8]

# -- Adjust column names for consistency and clarity 
MN_math23_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
MN_math22_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
MN_math21_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
MN_math19_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
MN_reading23_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
MN_reading22_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
MN_reading21_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']
MN_reading19_all.columns=['year', 'county', 'school', 'grade', 'subject', 'group,','total', 'does_not_meet', "partially_meets", "meets", 'exceeds', 'average']

# -- Replace 'no data' with NaN
MN_math23_all.replace('no data', np.nan, inplace=True)
MN_math22_all.replace('no data', np.nan, inplace=True)
MN_reading23_all.replace('no data', np.nan, inplace=True)
MN_reading22_all.replace('no data', np.nan, inplace=True)

# -- Drop NaNs in Count Level D Column
MN_math23_all.dropna(subset=['meets'], inplace=True)
MN_math22_all.dropna(subset=['meets'], inplace=True)
MN_math21_all.dropna(subset=['meets'], inplace=True)
MN_math19_all.dropna(subset=['meets'], inplace=True)
MN_reading23_all.dropna(subset=['meets'], inplace=True)
MN_reading22_all.dropna(subset=['meets'], inplace=True)
MN_reading21_all.dropna(subset=['meets'], inplace=True)
MN_reading19_all.dropna(subset=['meets'], inplace=True)

# -- group by year and sum
mnmath23=MN_math23_all.groupby("year").sum().reset_index()
mnmath22=MN_math22_all.groupby("year").sum().reset_index()
mnmath21=MN_math21_all.groupby("year").sum().reset_index()
mnmath19=MN_math19_all.groupby("year").sum().reset_index()
mnread23=MN_reading23_all.groupby("year").sum().reset_index()
mnread22=MN_reading22_all.groupby("year").sum().reset_index()
mnread21=MN_reading21_all.groupby("year").sum().reset_index()
mnread19=MN_reading19_all.groupby("year").sum().reset_index()

# -- combine results into a single dataframe
mn_test = pd.concat([mnmath23, mnmath22, mnmath21, mnmath19, mnread23, mnread22, mnread21, mnread19])
# Out:
# /var/folders/n4/qn58pcqs793_pw6d4r2zlbjc0000gn/T/ipykernel_75247/149035825.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MN_math23_all.replace('no data', np.nan, inplace=True)
# /var/folders/n4/qn58pcqs793_pw6d4r2zlbjc0000gn/T/ipykernel_75247/149035825.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MN_math22_all.replace('no data', np.nan, inplace=True)
# /var/folders/n4/qn58pcqs793_pw6d4r2zlbjc0000gn/T/ipykernel_75247/149035825.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# -- Calculate % of white students served versus students of color
charter_test['not meeting %']=(charter_test['does_not_meet']+charter_test['partially_meets'])/charter_test['total']* 100
charter_test['meeting %']=(charter_test['meets']+charter_test['exceeds'])/charter_test['total']* 100
mn_test['not meeting %']=(mn_test['does_not_meet']+mn_test['partially_meets'])/mn_test['total']*100
mn_test['meeting %']=(mn_test['meets']+mn_test['exceeds'])/mn_test['total']* 100

# -- Sub select reading and math subjects
charter_reading = charter_test[charter_test['subject'].str.contains('Reading')].sort_values(by='year')
charter_math = charter_test[charter_test['subject'].str.contains('MATH')].sort_values(by='year')
mn_reading=mn_test[mn_test['subject'] == 'Reading'].sort_values(by='year')
mn_math=mn_test[mn_test['subject'] == 'MATH'].sort_values(by='year')

# %%
# -- Plot enrollment trends for students of color over time
fig, ax = plt.subplots(figsize=(10, 7))
charter_reading.plot.bar(x='year', y='meeting %', label='Charter Schools', position=0, color='r', ax=ax, width=0.4)
mn_reading.plot.bar(x='year', y='meeting %', label='All Public Schools', position=1, color='b', ax=ax, width=0.4)
plt.xlabel("School Year")  
plt.ylabel("% of student population by school type meeting or exceeding expectations in reading")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# -- Plot enrollment trends for students of color over time
fig, ax = plt.subplots(figsize=(10, 7))
charter_math.plot.bar(x='year', y='meeting %', label='Charter Schools', position=0, color='r', ax=ax, width=0.4)
mn_math.plot.bar(x='year', y='meeting %', label='All Public Schools', position=1, color='b', ax=ax, width=0.4)
plt.xlabel("School Year")  
plt.ylabel("% of student population by school type meeting or exceeding expectations in math")  
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
